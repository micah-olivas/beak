# %%
# List datasets
from beak.datasets import list_datasets
print(list_datasets())

# Load growth temps (once you have the file)
from beak.datasets import load_growth_temps
temps = load_growth_temps()

# Use utilities
from beak.utils import annotate_temperature, add_sequence_properties
annotated = annotate_temperature(tax_results)
